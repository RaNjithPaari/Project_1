# %%
27/03/2024

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/15.4 MB 7.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/15.4 MB 5.0 MB/s eta 0:00:03
#    -- ------------------------------------- 1.0/15.4 MB 6.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/15.4 MB 5.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/15.4 MB 5.5 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/15.4 MB 5.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/15.4 MB 5.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/15.4 MB 5.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/15.4 MB 5.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/15.4 MB 3.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.1/15.4 MB 4.0 MB/s eta 0:00:04
# ...

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",
 )


print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("create database saavi")

# %%
# 28/03/2024

# %%
mycursor.execute("create database if not exists savi")  # python SQL execution and also visualize this in web by using xampp

# %%
a = mycursor.execute("show databases")   

print(a)
# Out:
# None

# %%
a = mycursor.execute("show databases")            # to show the exixt db
for i in mycursor:
    print(i)
# Out:
# ('information_schema',)
# ('mukhilan',)
# ('mysql',)
# ('paari',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('saavi',)
# ('savi',)
# ('test',)

# %%
mycursor.execute("drop database saavi")   # to delete the created db and also its permanent delete

# %%
a = mycursor.execute("show databases")            # to show the exixt db
for i in mycursor:
    print(i)
# Out:
# ('information_schema',)
# ('mukhilan',)
# ('mysql',)
# ('paari',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('savi',)
# ('test',)

# %%
SQL DML (data manipulation language) commands =

# %%
mycursor.execute("create table savi.guuvi(name varchar(21))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'guuvi' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mycursor.execute("create table savi.guuvi(name varchar(21))")
#
# ...

# %%
mycursor.execute("use savi")

# %%
mycursor.execute("create table guuvi1(name varchar(20))")

# %%
mycursor.execute("create table paari.guvi(name varchar(20))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'guvi' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 mycursor.execute("create table paari.guvi(name varchar(20))")
#
# ...

# %%
mycursor.execute("create table guuvi2(name varchar(20))")

# %%
mycursor.execute("CREATE TABLE lucky (salary INT(6),weight DECIMAL(5,3),insurance BOOLEAN)")


#decimal first value is total number of digits(including pre and post decimal digits) and swecond value is for after point
#second value cannot be greater than first value

# %%
mycursor.execute("INSERT INTO lucky (salary, weight, insurance) VALUES (850000, 98.855, 1)")

# %%
mycursor.execute("INSERT INTO `lucky` (`salary`, `weight`, `insurance`) VALUES ('80000', '99.555', '1')")

# %%
mydb.commit()

# %%
#Alter table
#add a new column at first
#mycursor.execute("ALTER TABLE lucky ADD covid VARCHAR(5) FIRST")
#mycursor.execute("ALTER TABLE lucky ADD status VARCHAR(5) LAST")
mycursor.execute("ALTER TABLE lucky ADD NO VARCHAR(5) FIRST")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate column name 'NO'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 5
#       1 #Alter table
#       2 #add a new column at first
# ...

# %%
#alter table
#add new column after some column name
mycursor.execute("ALTER TABLE lucky ADD covid_status VARCHAR(5) AFTER covid")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'covid' in 'lucky'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 3
#       1 #alter table
#       2 #add new column after some column name
# ...

# %%
mycursor.execute("ALTER TABLE lucky ADD VIRUSS VARCHAR(5) BEFORE covid")
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'BEFORE covid' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
#DROP column example
#The ROLLBACK command is the transactional command used to undo transactions that have not already been saved to the database.
mycursor.execute("ALTER TABLE lucky DROP COLUMN covid_status  ")
mydb.rollback()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\DELL\Desktop\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'savi.lucky' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[29], line 3
#       1 #DROP column example
# ...

# %%
#MODIFY(tochange the definition of th column)
mycursor.execute("ALTER TABLE lucky MODIFY covid INT ")
mydb.commit()

# %%
#rename column
mycursor.execute("ALTER TABLE lucky CHANGE COLUMN covid covidnew INT")
mydb.commit()

# %%
# To Rename table
mycursor.execute("RENAME TABLE savi.lucky TO savi.new_namer")

# %%
# move the file
mycursor.execute("RENAME TABLE savi.new_namer TO paari.new_namer")

# %%
# 01/04/2024

# %%
mycursor.execute("CREATE TABLE savi.date12 (datein DATE)")
#mycursor.execute("INSERT INTO date (datein) VALUES ( CURDATE())")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'date12' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mycursor.execute("CREATE TABLE savi.date12 (datein DATE)")
# ...

# %%
mycursor.execute("use savi")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Lost connection to MySQL server during query
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 mycursor.execute("use savi")
#
# ...

# %%
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (NOW())")

mydb.commit()


#whatever date format given into DATE datatypw will consider in the sameway

# %%
mycursor.execute("CREATE TABLE datestrinnn (datein VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'datestrinnn' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mycursor.execute("CREATE TABLE datestrinnn (datein VARCHAR(255))")
#
# ...

# %%
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (NOW())")#date and time
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MONTHNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DAYNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (HOUR(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MINUTE(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_ADD(NOW(),INTERVAL -10 DAY))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_FORMAT(NOW(),'%W %D %M %Y %T %H'))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (UTC_DATE())")#UTC_TIME,UTC_TIMESTAMP
mydb.commit()

# %%
# !pip install tabulate

# %%
from tabulate import tabulate

# %%
mycursor.execute("select * from savi.diabetes")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# ...

# %%
mycursor.execute("select Age,Outcome from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-----------+
# |   Age |   Outcome |
# |-------+-----------|
# |    50 |         1 |
# |    31 |         0 |
# |    32 |         1 |
# |    21 |         0 |
# |    33 |         1 |
# |    30 |         0 |
# |    26 |         1 |
# |    29 |         0 |
# |    53 |         1 |
# |    54 |         1 |
# |    30 |         0 |
# |    34 |         1 |
# |    57 |         0 |
# |    59 |         1 |
# |    51 |         1 |
# |    32 |         1 |
# |    31 |         1 |
# |    31 |         1 |
# |    33 |         0 |
# |    32 |         1 |
# |    27 |         0 |
# |    50 |         0 |
# |    41 |         1 |
# |    29 |         1 |
# |    51 |         1 |
# |    41 |         1 |
# |    43 |         1 |
# |    22 |         0 |
# |    57 |         0 |
# |    38 |         0 |
# |    60 |         0 |
# |    28 |         1 |
# |    22 |         0 |
# |    28 |         0 |
# |    45 |         0 |
# |    33 |         0 |
# |    35 |         0 |
# |    46 |         1 |
# ...

# %%
mycursor.execute("select Age,Outcome from savi.diabetes limit 10")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-----------+
# |   Age |   Outcome |
# |-------+-----------|
# |    50 |         1 |
# |    31 |         0 |
# |    32 |         1 |
# |    21 |         0 |
# |    33 |         1 |
# |    30 |         0 |
# |    26 |         1 |
# |    29 |         0 |
# |    53 |         1 |
# |    54 |         1 |
# +-------+-----------+

# %%
mycursor.execute("select * from savi.diabetes where Outcome =1")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             3 |        78 |              50 |              32 |        88 |  31   |                      0.248 |    26 |         1 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Pregnancies >= 5")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# |            10 |       115 |               0 |               0 |         0 |  35.3 |                      0.134 |    29 |         0 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Pregnancies >= 5")
mycursor.execute("select * from savi.diabetes where Insulin >= 35")
mycursor.execute("select * from savi.diabetes where BloodPressure <= 40")
mycursor.execute("select * from savi.diabetes where BMI = 30")
mycursor.execute("select * from savi.diabetes where Glucose >= 100") 
mycursor.execute("select * from savi.diabetes where Outcome != 1")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# |            10 |       115 |               0 |               0 |         0 |  35.3 |                      0.134 |    29 |         0 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Outcome = 1 and Pregnancies = 1")  # AND condition 
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |       189 |              60 |              23 |       846 |  30.1 |                      0.398 |    59 |         1 |
# |             1 |       115 |              70 |              30 |        96 |  34.6 |                      0.529 |    32 |         1 |
# |             1 |       122 |              90 |              51 |       220 |  49.7 |                      0.325 |    31 |         1 |
# |             1 |       163 |              72 |               0 |         0 |  39   |                      1.222 |    33 |         1 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Outcome = 1 or Pregnancies = 1") # OR  condition
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Age >= 30 and Age <= 40")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# ...

# %%
mycursor.execute("select * from savi.diabetes where Age >= 30 and Age <= 40 or (Pregnancies >=3 and Pregnancies <=5)") 
mycursor.execute("select * from savi.diabetes where Age >= 30 and Age <= 40 or (Pregnancies in (3,4,5))")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# ...

# %%
mycursor.execute("select Age + BloodPressure as guvi from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------+
# |   guvi |
# |--------|
# |    122 |
# |     97 |
# |     96 |
# |     87 |
# |     73 |
# |    104 |
# |     76 |
# |     29 |
# |    123 |
# |    150 |
# |    122 |
# |    108 |
# |    137 |
# |    119 |
# |    123 |
# |     32 |
# |    115 |
# |    105 |
# |     63 |
# |    102 |
# |    115 |
# |    134 |
# |    131 |
# |    109 |
# |    145 |
# |    111 |
# |    119 |
# |     88 |
# |    139 |
# |    130 |
# |    135 |
# |    104 |
# |     80 |
# |    120 |
# |    123 |
# |     93 |
# |    111 |
# |    122 |
# |     95 |
# |    128 |
# |     90 |
# |    121 |
# |    140 |
# |    164 |
# |    104 |
# |     91 |
# |     85 |
# |     92 |
# |     97 |
# |     24 |
# |    102 |
# |     76 |
# |     96 |
# |    148 |
# |    108 |
# |     71 |
# |    109 |
# |    119 |
# |    126 |
# |     86 |
# |     21 |
# |    111 |
# |     98 |
# |     82 |
# |    108 |
# |    106 |
# |    126 |
# |    146 |
# |     91 |
# |    112 |
# |     94 |
# |     90 |
# |    132 |
# ...

# %%
mycursor.execute("select Age + 10 , BloodPressure - 30 as guvi from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+--------+
# |   Age + 10 |   guvi |
# |------------+--------|
# |         60 |     42 |
# |         41 |     36 |
# |         42 |     34 |
# |         31 |     36 |
# |         43 |     10 |
# |         40 |     44 |
# |         36 |     20 |
# |         39 |    -30 |
# |         63 |     40 |
# |         64 |     66 |
# |         40 |     62 |
# |         44 |     44 |
# |         67 |     50 |
# |         69 |     30 |
# |         61 |     42 |
# |         42 |    -30 |
# |         41 |     54 |
# |         41 |     44 |
# |         43 |      0 |
# |         42 |     40 |
# |         37 |     58 |
# |         60 |     54 |
# |         51 |     60 |
# |         39 |     50 |
# |         61 |     64 |
# |         51 |     40 |
# |         53 |     46 |
# |         32 |     36 |
# |         67 |     52 |
# |         48 |     62 |
# |         70 |     45 |
# |         38 |     46 |
# |         32 |     28 |
# |         38 |     62 |
# |         55 |     48 |
# ...

# %%
mycursor.execute("select Age + 10 as Reage, BloodPressure - 30 as guvi from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------+--------+
# |   Reage |   guvi |
# |---------+--------|
# |      60 |     42 |
# |      41 |     36 |
# |      42 |     34 |
# |      31 |     36 |
# |      43 |     10 |
# |      40 |     44 |
# |      36 |     20 |
# |      39 |    -30 |
# |      63 |     40 |
# |      64 |     66 |
# |      40 |     62 |
# |      44 |     44 |
# |      67 |     50 |
# |      69 |     30 |
# |      61 |     42 |
# |      42 |    -30 |
# |      41 |     54 |
# |      41 |     44 |
# |      43 |      0 |
# |      42 |     40 |
# |      37 |     58 |
# |      60 |     54 |
# |      51 |     60 |
# |      39 |     50 |
# |      61 |     64 |
# |      51 |     40 |
# |      53 |     46 |
# |      32 |     36 |
# |      67 |     52 |
# |      48 |     62 |
# |      70 |     45 |
# |      38 |     46 |
# |      32 |     28 |
# |      38 |     62 |
# |      55 |     48 |
# |      43 |     30 |
# |      45 |     46 |
# |      56 |     46 |
# |      37 |     38 |
# |      66 |     42 |
# ...

# %%
mycursor.execute("WITH nethaji as (SELECT age,bmi from savi.diabetes where age<30)select age,bmi from nethaji where age>19")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-------+
# |   age |   bmi |
# |-------+-------|
# |    21 |  28.1 |
# |    26 |  31   |
# |    29 |  35.3 |
# |    27 |  39.3 |
# |    29 |  29   |
# |    22 |  23.2 |
# |    28 |  31.6 |
# |    22 |  24.8 |
# |    28 |  19.9 |
# |    27 |  38.2 |
# |    26 |  34   |
# |    25 |  42   |
# |    29 |  29.7 |
# |    22 |  28   |
# |    24 |   0   |
# |    22 |  19.4 |
# |    26 |  24.2 |
# |    21 |  23   |
# |    22 |  41.5 |
# |    21 |   0   |
# |    24 |  25.4 |
# |    25 |  19.6 |
# |    27 |  28.9 |
# |    28 |  32.9 |
# |    26 |  28.6 |
# |    23 |  35.1 |
# |    22 |  32   |
# |    22 |  24.7 |
# |    27 |  37.7 |
# |    26 |  43.2 |
# |    24 |  25   |
# |    22 |  22.4 |
# |    22 |   0   |
# |    22 |  24.6 |
# |    27 |  32.4 |
# |    26 |  38.5 |
# |    24 |  26.5 |
# |    21 |  19.1 |
# |    21 |  24.7 |
# |    24 |  31.6 |
# |    22 |  20.4 |
# |    23 |  28.7 |
# |    22 |  26.1 |
# |    21 |  22.5 |
# |    24 |  26.6 |
# |    27 |  39.6 |
# |    21 |  28.7 |
# ...

# %%
mycursor.execute("select bmi from diabetes where age between 20 and 30")                #BETWEEN
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+
# |   bmi |
# |-------|
# |  28.1 |
# |  25.6 |
# |  31   |
# |  35.3 |
# |  37.6 |
# |  39.3 |
# |  29   |
# |  23.2 |
# |  31.6 |
# |  24.8 |
# |  19.9 |
# |  38.2 |
# |  34   |
# |  42   |
# |  29.7 |
# |  28   |
# |   0   |
# |  19.4 |
# |  24.2 |
# |  24.4 |
# |  23   |
# |  41.5 |
# |   0   |
# |  25.4 |
# |  19.6 |
# |  28.9 |
# |  32.9 |
# |  28.6 |
# |  35.1 |
# |  32   |
# |  24.7 |
# |  37.7 |
# |  43.2 |
# |  25   |
# |  22.4 |
# |   0   |
# |  24.6 |
# |  32.4 |
# |  38.5 |
# |  26.5 |
# |  19.1 |
# |  24.7 |
# |  31.6 |
# |  20.4 |
# |  28.7 |
# |  26.1 |
# |  22.5 |
# |  26.6 |
# |  39.6 |
# |  28.7 |
# |  22.4 |
# |  34.3 |
# |  37.4 |
# |  33.3 |
# |  31.2 |
# |  34   |
# |  33.7 |
# |  28.2 |
# |  23.2 |
# |  53.2 |
# |  34.2 |
# |  33.6 |
# |  33.3 |
# |  55   |
# |  42.9 |
# |  33.3 |
# |  34.5 |
# |  21.1 |
# |  30.8 |
# |  28.7 |
# |  31.2 |
# |  36.9 |
# |  32.5 |
# |  32.8 |
# |   0   |
# |  27.3 |
# |  37.4 |
# |  40.6 |
# |  24.6 |
# |  25.2 |
# ...

# %%
# Mathematical Operations

# %%
mycursor.execute("SELECT COUNT(outcome) from savi.diabetes where age>50 and outcome=1 ")
out=mycursor.fetchall()           
from tabulate import tabulate     
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------------+
# |   COUNT(outcome) |
# |------------------|
# |               38 |
# +------------------+

# %%
mycursor.execute("SELECT MAX(AGE) as oldest ,MIN(AGE) as youngest from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------+------------+
# |   oldest |   youngest |
# |----------+------------|
# |       81 |         21 |
# +----------+------------+

# %%
mycursor.execute("SELECT MAX(pregnancies) as highest ,MIN(pregnancies) as lowest from savi.diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------+----------+
# |   highest |   lowest |
# |-----------+----------|
# |        17 |        0 |
# +-----------+----------+

# %%
mycursor.execute("select sum(age)/count(age) as average_age from savi.diabetes where outcome=1")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+
# |   average_age |
# |---------------|
# |       37.0672 |
# +---------------+

# %%
mycursor.execute("select AVG(age) as average_age from savi.diabetes where outcome=1")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+
# |   average_age |
# |---------------|
# |       37.0672 |
# +---------------+

# %%
mycursor.execute("SELECT * FROM savi.diabetes where glucose >(SELECT AVG(glucose) from savi.diabetes)")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             2 |       197 |              70 |              45 |       543 |  30.5 |                      0.158 |    53 |         1 |
# ...

# %%
mycursor.execute("SHOW COLUMNS FROM diabetes")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------+--------------+--------+-------+-----------+---------+
# | Field                    | Type         | Null   | Key   | Default   | Extra   |
# |--------------------------+--------------+--------+-------+-----------+---------|
# | Pregnancies              | int(2)       | YES    |       |           |         |
# | Glucose                  | int(3)       | YES    |       |           |         |
# | BloodPressure            | int(3)       | YES    |       |           |         |
# | SkinThickness            | int(2)       | YES    |       |           |         |
# | Insulin                  | int(3)       | YES    |       |           |         |
# | BMI                      | decimal(3,1) | YES    |       |           |         |
# | DiabetesPedigreeFunction | decimal(4,3) | YES    |       |           |         |
# | Age                      | int(2)       | YES    |       |           |         |
# ...

# %%
mycursor.execute("select age,outcome,pregnancies from diabetes where outcome=1 and pregnancies<5 ORDER BY age DESC")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-----------+---------------+
# |   age |   outcome |   pregnancies |
# |-------+-----------+---------------|
# |    70 |         1 |             4 |
# |    67 |         1 |             4 |
# |    66 |         1 |             2 |
# |    62 |         1 |             2 |
# |    62 |         1 |             0 |
# |    61 |         1 |             4 |
# |    60 |         1 |             4 |
# |    59 |         1 |             1 |
# |    56 |         1 |             4 |
# |    53 |         1 |             2 |
# |    52 |         1 |             0 |
# |    52 |         1 |             3 |
# |    52 |         1 |             1 |
# |    52 |         1 |             2 |
# |    47 |         1 |             1 |
# |    46 |         1 |             4 |
# |    46 |         1 |             1 |
# |    45 |         1 |             1 |
# |    45 |         1 |             4 |
# |    44 |         1 |             3 |
# |    43 |         1 |             1 |
# |    42 |         1 |             1 |
# ...

# %%
mycursor.execute("select age,bmi,outcome from diabetes order by age ASC")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-------+-----------+
# |   age |   bmi |   outcome |
# |-------+-------+-----------|
# |    21 |  42.7 |         0 |
# |    21 |  25.1 |         0 |
# |    21 |  26   |         0 |
# |    21 |  40.6 |         0 |
# |    21 |  30.8 |         0 |
# |    21 |  33.6 |         1 |
# |    21 |  18.2 |         0 |
# |    21 |  22.5 |         0 |
# |    21 |  28.7 |         0 |
# |    21 |  29.2 |         0 |
# |    21 |   0   |         0 |
# |    21 |  21.8 |         0 |
# |    21 |  34.6 |         1 |
# |    21 |  26.2 |         0 |
# |    21 |  19.1 |         0 |
# |    21 |  21   |         0 |
# |    21 |   0   |         0 |
# |    21 |  35.8 |         0 |
# |    21 |   0   |         0 |
# |    21 |  35.7 |         0 |
# |    21 |  23   |         0 |
# |    21 |  24.8 |         0 |
# |    21 |  25.4 |         0 |
# |    21 |  23.7 |         0 |
# |    21 |  36.9 |         0 |
# |    21 |  33.2 |         0 |
# |    21 |  24.7 |         0 |
# |    21 |  25.2 |         0 |
# ...

# %%
mycursor.execute("select count(*) from savi.diabetes where  outcome = 0  and bloodpressure in \
( select bloodpressure from savi.diabetes where bloodpressure > 40 and bloodpressure < 91 )")
out=mycursor.fetchall()           # Fetchall is for taken the datas
from tabulate import tabulate      # import tabulates as tb also allowed
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   count(*) |
# |------------|
# |        458 |
# +------------+

# %%
mycursor.execute("select count(*) from savi.diabetes where age>40 and pregnancies in \
                (select pregnancies from savi.diabetes where pregnancies between 2 and 7 ) \
                and glucose in(select glucose from savi.diabetes where glucose between 140 and 180) and outcome=0")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   count(*) |
# |------------|
# |          9 |
# +------------+

# %%
mycursor.execute("SELECT pregnancies,count(*) FROM savi.diabetes GROUP BY pregnancies ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+------------+
# |   pregnancies |   count(*) |
# |---------------+------------|
# |             0 |        111 |
# |             1 |        135 |
# |             2 |        103 |
# |             3 |         75 |
# |             4 |         68 |
# |             5 |         57 |
# |             6 |         50 |
# |             7 |         45 |
# |             8 |         38 |
# |             9 |         28 |
# |            10 |         24 |
# |            11 |         11 |
# |            12 |          9 |
# |            13 |         10 |
# |            14 |          2 |
# |            15 |          1 |
# |            17 |          1 |
# +---------------+------------+

# %%
mycursor.execute("SELECT outcome,count(*) FROM savi.diabetes GROUP BY Outcome ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------+------------+
# |   outcome |   count(*) |
# |-----------+------------|
# |         0 |        500 |
# |         1 |        268 |
# +-----------+------------+

# %%
mycursor.execute("SELECT outcome,age,count(*) FROM savi.diabetes GROUP BY Outcome,Age ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------+-------+------------+
# |   outcome |   age |   count(*) |
# |-----------+-------+------------|
# |         0 |    21 |         58 |
# |         0 |    22 |         61 |
# |         0 |    23 |         31 |
# |         0 |    24 |         38 |
# |         0 |    25 |         34 |
# |         0 |    26 |         25 |
# |         0 |    27 |         24 |
# |         0 |    28 |         25 |
# |         0 |    29 |         16 |
# |         0 |    30 |         15 |
# |         0 |    31 |         11 |
# |         0 |    32 |          7 |
# |         0 |    33 |          7 |
# |         0 |    34 |         10 |
# |         0 |    35 |          5 |
# |         0 |    36 |          6 |
# |         0 |    37 |         13 |
# |         0 |    38 |          6 |
# |         0 |    39 |          9 |
# |         0 |    40 |          7 |
# |         0 |    41 |          9 |
# |         0 |    42 |         11 |
# |         0 |    43 |          2 |
# |         0 |    44 |          3 |
# ...

# %%
mycursor.execute("SELECT outcome,age,bmi,count(*) FROM savi.diabetes GROUP BY Outcome,Age,BMI ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File e:\GUVI\New folder\Learning\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Lost connection to MySQL server during query
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[57], line 1
# ...

# %%
mycursor.execute("SELECT CASE \
        WHEN bmi < 18.5 THEN 'Underweight' \
        WHEN bmi BETWEEN 18.5 AND 24.9 THEN 'Normal' \
        WHEN bmi BETWEEN 25 AND 29.9 THEN 'Overweight' \
        ELSE 'Obese' \
      END \
     AS bmi_category, \
   COUNT(*) AS patient_count \
FROM savi.diabetes \
GROUP BY bmi_category")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+-----------------+
# | bmi_category   |   patient_count |
# |----------------+-----------------|
# | Normal         |             102 |
# | Obese          |             472 |
# | Overweight     |             179 |
# | Underweight    |              15 |
# +----------------+-----------------+

# %%
# TIBD CLOUD
# https://tidbcloud.com/console/clusters/10451111019444556340/chat2query

# %%
import mysql.connector

connection = mysql.connector.connect(
  host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port = 4000,
  user = "3HCPpUXFqTgLaZb.root",
  password = "z4CB7TkOk6IGyalf",
  database = "test",

)

mycursor = connection.cursor(buffered=True)

# %%
mycursor.execute("create database paari")

# %%
mycursor.execute("drop database paari")

# %%
a = mycursor.execute("show databases")            # to show the exixt db
for i in mycursor:
    print(i)
# Out:
# ('INFORMATION_SCHEMA',)
# ('PERFORMANCE_SCHEMA',)
# ('mysql',)
# ('test',)

# %%
mycursor.execute("select * from savi.diabetes")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# ...

# %%
# 03/04/2024

# %%
mycursor.execute("""
   SELECT Age, Pregnancies, COUNT(*) OVER (PARTITION BY Pregnancies ORDER BY Age DESC) as Countw
   FROM savi.diabetes
""")
out = mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description], tablefmt='psql'))
# Out:
# +-------+---------------+----------+
# |   Age |   Pregnancies |   Countw |
# |-------+---------------+----------|
# |    67 |             0 |        1 |
# |    65 |             0 |        2 |
# |    62 |             0 |        3 |
# |    59 |             0 |        4 |
# |    58 |             0 |        5 |
# |    52 |             0 |        6 |
# |    46 |             0 |        8 |
# |    46 |             0 |        8 |
# |    44 |             0 |       10 |
# |    44 |             0 |       10 |
# |    41 |             0 |       11 |
# |    38 |             0 |       12 |
# |    36 |             0 |       13 |
# |    35 |             0 |       15 |
# |    35 |             0 |       15 |
# |    33 |             0 |       17 |
# |    33 |             0 |       17 |
# |    32 |             0 |       19 |
# |    32 |             0 |       19 |
# |    31 |             0 |       23 |
# |    31 |             0 |       23 |
# |    31 |             0 |       23 |
# ...
